# %%
import networkx as nx
import matplotlib.pyplot as plt
import pylab
import warnings
warnings.filterwarnings("ignore")

G = nx.read_edgelist("Email-Enron.txt",create_using=nx.Graph(), nodetype = int, comments="#")
degree_sequence=sorted(nx.degree(G).values(),reverse=True) # degree sequence
#print "Degree sequence", degree_sequence
dmax=max(degree_sequence)

plt.loglog(degree_sequence,'b-',marker='o')
plt.title("Degree rank plot")
plt.ylabel("degree")
plt.xlabel("rank")

# draw graph in inset
plt.axes([0.45,0.45,0.45,0.45])
Gcc=sorted(nx.connected_component_subgraphs(G), key = len, reverse=True)[0]
pos=nx.spring_layout(Gcc)
plt.axis('off')
nx.draw_networkx_nodes(Gcc,pos,node_size=20)
nx.draw_networkx_edges(Gcc,pos,alpha=0.4)

plt.savefig("degree_histogram.png")
plt.show()

# %%
nx.degree(G)
# Out:
# {0: 1,
#  1: 70,
#  2: 1,
#  3: 5,
#  4: 8,
#  5: 62,
#  6: 9,
#  7: 14,
#  8: 1,
#  9: 39,
#  10: 4,
#  11: 5,
#  12: 5,
#  13: 15,
#  14: 1,
#  15: 6,
#  16: 5,
#  17: 1,
#  18: 5,
#  19: 3,
#  20: 1,
#  21: 4,
#  22: 1,
#  23: 1,
#  24: 1,
#  25: 2,
#  26: 1,
#  27: 78,
#  28: 1,
#  29: 1,
#  30: 2,
#  31: 3,
#  32: 2,
#  33: 1,
#  34: 1,
#  35: 3,
#  36: 1,
#  37: 1,
#  38: 1,
#  39: 18,
#  40: 1,
#  41: 3,
#  42: 4,
#  43: 1,
#  44: 10,
#  45: 25,
#  46: 112,
#  47: 1,
#  48: 1,
#  49: 10,
#  50: 11,
#  51: 7,
#  52: 3,
#  53: 111,
#  54: 102,
#  55: 16,
#  56: 309,
#  57: 1,
#  58: 2,
#  59: 11,
#  60: 12,
#  61: 1,
#  62: 12,
#  63: 1,
#  64: 1,
#  65: 4,
#  66: 1,
#  67: 1,
#  68: 1,
#  69: 6,
#  70: 2,
#  71: 1,
#  72: 377,
#  73: 127,
#  74: 293,
#  75: 232,
#  76: 815,
#  77: 4,
#  78: 339,
#  79: 119,
#  80: 271,
#  81: 120,
#  82: 212,
#  83: 201,
#  84: 48,
#  85: 32,
#  86: 125,
#  87: 44,
#  88: 284,
#  89: 247,
#  90: 366,
#  91: 172,
#  92: 69,
#  93: 455,
# ...

# %%
print("Grado Máximo: ",dmax)
dmin=min(degree_sequence)
print("Grado Mínimo: ",dmin)
# Out:
# Grado Máximo:  1383
# Grado Mínimo:  1

# %%
#def gradosGrafo(G):
#retorna los valores únicos de los grados en una lista ordenada para el grafo G
#lista = []
#print(nx.degree(G))
    #return sorted(set(lista))

#print(gradosGrafo(G))

dg=0
count=0
for d in range(len(G.degree())):
    dg=dg+G.degree(d)
    if G.degree(d)==dmax:
        print("Grado",d,": ",G.degree(d))
    
    if G.degree(d)==dmin:
        count=count+1
print("Conteo de minimos: ",count)
# Out:
# Grado 5038 :  1383
# Conteo de minimos:  11211

# %%
print(nx.info(G),"\n")
# Out:
# Name:
# Type: Graph
# Number of nodes: 36692
# Number of edges: 183831
# Average degree:  10.0202
